# %% [markdown]
# #Theory Question

# %% [markdown]
# 1. What is Python, and why is it popular?
#
#  -Python is a programming language that is easy to learn and use. It is popular because it has simple, readable code and can be used for many different tasks, like building websites, analyzing data, and creating artificial intelligence.
#
#
# 2. What is an interpreter in Python?
#
#   -An interpreter in Python is a tool that reads and runs your Python code one line at a time. It makes it easy to test and see results quickly.
#
#
# 3. What are pre-defined keywords in Python?
#
#  -Pre-defined keywords in Python are special words that have a specific meaning and purpose in the language. You can't use them as names for variables or functions. Ex:if,else,while,for.
#
# 4. Can keywords be used as variable names?
#
#  - No keywords can't be used as variable names because they have special meanings in Python.
#
# 5. What is mutability in Python?
#
#  -n Python, mutability means whether an object can change after it's created & Ex:list,dict,set.
#
# 6. Why are lists mutable, but tuples are immutable?
#  -Lists are mutable because they are meant to be changed .Tuples are immutable because they are meant to stay the same and protect their data.
#
# 7. What are logical operators in Python?
#   - True if both conditions are true.
#   - True if at least one condition is true.
#   - Reverses the condition.
# 8. What is type casting in Python?
#   - Type casting in Python means changing a value from one type to another.
#
# 9.  What is the difference between implicit and explicit type casting?
#   - Implicit: Python does it for you automatically
#   - Explicit: You do it yourself
#
# 10. What is the purpose of conditional statements in Python?
#
#     - The purpose of conditional statements in Python is to make decisions in your code based on condition.
#
#
# 11.  How does the elif statement work?
#
#       - The elif statement helps you check multiple conditions in a program, providing different outcomes based on different scenarios.
#
# 12. What is the difference between for and while loops?
#   - for loop iterates over sequences with a known number of iterations.
#   - whileloop repeats as long as a condition is True.
#
# 13. Describe a scenario where a while loop is more suitable than a for loop?
#
#   - Use a while loop when you don't know how many times you need to loop until a specific condition is fulfilled.

# %% [markdown]
# Practical

# %%
#.1 Write a Python program to print "Hello, World!"?

 - print("Hello, World!")

#.2 Write a Python program that displays your name and age?

  - # Ask for the user's name
name = input("Please enter your name: ")

# Ask for the user's age
age = input("Please enter your age: ")

# Display the name and age
print(f"Your name is {name} and you are {age} years old.")


#.3 Write code to print all the pre-defined keywords in Python using the keyword library?
  - import keyword

# Get all the keywords in Python
keywords = keyword.kwlist

# Print the keywords
print("The pre-defined keywords in Python are:")
for kw in keywords:
    print(kw)

#.4 Write a program that checks if a given word is a Python keyword?
  - import keyword

# Function to check if a word is a Python keyword
def is_keyword(word):
    return keyword.iskeyword(word)

# Input: Ask the user to enter a word
word = input("Enter a word to check if it's a Python keyword: ")

# Check if the word is a Python keyword
if is_keyword(word):
    print(f"'{word}' is a Python keyword.")
else:
    print(f"'{word}' is not a Python keyword.")
5. Write a function to demonstrate the behavior of mutable and immutable arguments?
  - def demo_mutable_immutable(lst, num):
    print("Inside function:")

    # Mutable argument (list)
    print("Before modifying list:")
    print(f"lst: {lst}")
    lst.append(100)
    print(f"lst after modification: {lst}")

    # Immutable argument (integer)
    print("Before modifying integer:")
    print(f"num: {num}")
    num += 10
    print(f"num after modification: {num}")

    print("\n")

# Mutable argument
mutable_list = [1, 2, 3]
# Immutable argument
immutable_num = 50

# Call the function
demo_mutable_immutable(mutable_list, immutable_num)

# Check values outside the function
print("Outside function:")
print(f"mutable_list: {mutable_list}")
print(f"immutable_num: {immutable_num}")

#.6 Write a program to demonstrate the use of logical operators?
 - # Function to demonstrate logical operators
def demo_logical_operators(a, b, c):
    print(a > 5 and b < 10)  # 'and' operator
    print(a > 10 or c == 20)  # 'or' operator
    print(not (b > 15))  # 'not' operator

# Test values
a = 8
b = 7
c = 20

# Call the function
demo_logical_operators(a, b, c)

#.7 Write code to demonstrate type casting with list elements?
  - # Function to demonstrate type casting with list elements
def demo_type_casting(lst):
    print("Original list:", lst)

    # Convert all elements to integers
    int_list = [int(x) for x in lst]
    print("List after converting to integers:", int_list)

    # Convert all elements to floats
    float_list = [float(x) for x in lst]
    print("List after converting to floats:", float_list)

    # Convert all elements to strings
    str_list = [str(x) for x in lst]
    print("List after converting to strings:", str_list)

#.8 Write a program that checks if a number is positive, negative, or zero?
  - # Function to check if a number is positive, negative, or zero
def check_number(num):
    if num > 0:
        print(f"{num} is a positive number.")
    elif num < 0:
        print(f"{num} is a negative number.")
    else:
        print("The number is zero.")

#.9 Write a for loop to print numbers from 1 to 100 ?
  - # Loop to print numbers from 1 to 100
for i in range(1, 101):
    print(i)
#.10 Write a Python program to find the sum of all evennumbers between 1and500?
  -# Program to find the sum of all even numbers between 1 and 500
def sum_even_numbers():
    total = 0
    for i in range(1, 501):
        if i % 2 == 0:
            total += i
    return total

# Call the function and print the result
sum_result = sum_even_numbers()
print(f"The sum of all even numbers between 1 and 500 is: {sum_result}")
#.11 Write a Python program to calculate the factorial of a number provided by the user using a while loop.
  - # Function to calculate factorial using a while loop
def factorial(n):
    result = 1
    i = 1
    while i <= n:
        result *= i
        i += 1
    return result

# Ask user for input
n = int(input("Enter a number: "))

# Calculate and print factorial
print(f"The factorial of {n} is: {factorial(n)}")
